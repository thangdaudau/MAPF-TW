# %%
import os
import sys

LIB_SOURCE = os.path.join(os.path.abspath('../../.'), 'build', 'core', 'bindings')
sys.path.append(LIB_SOURCE)

from mapf_solver import CBS

# %%
def process_map_yaml(path: str) -> tuple[int, int, list[list[int]], list[list[int]], list[tuple[int, int]], list[tuple[int, int, int, int]]]:
    """
    Returns: n, m, map, g, edges, agents

    map[i][j]: 0 - nothing, 1 - agents, 2 - goal, 3 - obstacle
    """
    pass

# %%
from keras.layers import Input
from keras.layers import BatchNormalization, Dense, Conv2D, Flatten, Concatenate
from keras.layers import Multiply, Dot
import gym

# hyperparameters here
N_ts = 300000
eta = 0.7
...

def generate_senario(...) -> ...:
    ...

def RRAStar(...) -> ...:
    ...

def get_agents_priority(...) -> ...:
    ...


def get_observation(...) -> ...:
    ...

def compute_S(...) -> ...:
    ...

def compute_P(...) -> ...:
    ... 

def compute_E(...) -> ...:
    ...

class Env(...):
    ...

class ObservationEncoder(...):
    ...

class CommuicationBlock(...):
    ...

class PDCLModel(...):
    ...


def training(...) -> ...:
    ...
