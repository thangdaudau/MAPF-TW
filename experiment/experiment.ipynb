# %%
import os
import sys
sys.path.append(os.path.abspath('.././'))

from core.wrapper import CBS, ICBS, GCBS
from core.wrapper import set_time_limit, set_release_gil

set_time_limit(60)
set_release_gil(True)

# %%
agent_count_per_scenario = [10, 30, 50, 70, 100, 120, 150]
scenario_count = 100

def generate_one_scenario(map_path: str, agent_count: int) -> tuple[int, int, list[list[int]], list[list[int]], list[tuple[int, int]], list[tuple[int, int, int, int]]]:
    """
    Returns: n, m, map, g, edges, agents

    map[i][j]: 0 - nothing, 1 - agents, 2 - goal, 3 - obstacle
    """
    ...

def multiprocessing_run_scenarios(scenario_count: int, agent_count: int) -> tuple[float, float]:
    """
    Returns: success rate, mean ratio of GCBS and CBS (if both success)
    """
    import multiprocessing
    ...
